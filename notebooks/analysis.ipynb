# %% [markdown]
# # Rebot ML: Exploratory Data Analysis
# This notebook is for data exploration, visualization, and hypothesis testing.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load ground truth for analysis
df = pd.read_json('../data/raw/resumes.json')
df.head()
