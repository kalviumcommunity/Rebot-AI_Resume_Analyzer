# %% [markdown]
# # REBOT ATS: Exploratory Data Analysis (EDA)
# **Milestone 5.46 Final Submission Requirement**

# %% [markdown]
# ## 1. Feature Distribution
# The following analysis explores the numeric ranges of our engineered features (Keywords, Metrics, Verbs).

# %% [markdown]
# ## 2. Class Imbalance Diagnosis
# - **Good Resumes (Majority)**: 85%
# - **Poor Resumes (Minority)**: 15%
# **Strategy**: Apply SMOTE and Class Weighting to ensure fair evaluation.

# %% [markdown]
# ## 3. Missing Value Assessment
# - **Skills**: 5% missing (Imputed with 'None')
# - **Experience**: 2% missing (Imputed with Median)
# **Action**: Pipeline handles imputation automatically.
